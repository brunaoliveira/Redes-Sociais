# %%
import numpy as np 
import pandas as pd 
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# importing the data
df1 = pd.read_csv('./covid_19_dataset/time_series_covid_19_deaths_US.csv')
df2 = pd.read_csv('./covid_19_dataset/time_series_covid_19_recovered.csv')
df3 = pd.read_csv('./covid_19_dataset/time_series_covid_19_confirmed_US.csv')
df4 = pd.read_csv('./covid_19_dataset/covid_19_data.csv')
df5 = pd.read_csv('./covid_19_dataset/time_series_covid_19_confirmed.csv')
df6 = pd.read_csv('./covid_19_dataset/time_series_covid_19_deaths.csv')

# %% [markdown]
# # USA data

# %% [markdown]
# ### Deaths

# %%
df1.style.set_caption("USA Deaths")
df1.head()
# pandas_profiling.ProfileReport(df1)
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 2/18/21  2/19/21  2/20/21  2/21/21  2/22/21  \
# 0  32.539527 -86.644082  ...      84       85       85       85       85
# 1  30.727750 -87.722071  ...     254      262      262      262      262
# 2  31.868263 -85.387129  ...      49       49       50       50       50
# 3  32.996421 -87.125115  ...      57       58       58       58       58
# 4  33.982109 -86.567906  ...     121      125      125      125      125
#
#    2/23/21  2/24/21  2/25/21  2/26/21  2/27/21
# ...

# %%
df1.describe()
# Out:
#                 UID        code3          FIPS          Lat        Long_  \
# count  3.340000e+03  3340.000000   3330.000000  3340.000000  3340.000000
# mean   8.342958e+07   834.491617  33061.684685    36.707212   -88.601474
# std    4.315345e+06    36.498055  18638.940791     9.062922    21.718982
# min    1.600000e+01    16.000000     60.000000   -14.271000  -174.159600
# 25%    8.401811e+07   840.000000  19079.500000    33.895587   -97.790204
# 50%    8.402921e+07   840.000000  31014.000000    38.002344   -89.486710
# 75%    8.404612e+07   840.000000  47130.500000    41.573069   -82.311265
# max    8.410000e+07   850.000000  99999.000000    69.314792   145.673900
#
#          Population  1/22/20  1/23/20  1/24/20  1/25/20  ...       2/18/21  \
# count  3.340000e+03   3340.0   3340.0   3340.0   3340.0  ...   3340.000000
# mean   9.966039e+04      0.0      0.0      0.0      0.0  ...    147.646108
# std    3.242549e+05      0.0      0.0      0.0      0.0  ...    578.319802
# ...

# %% [markdown]
# ### Recovered

# %%
df2.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/18/21  2/19/21  2/20/21  \
# 0        0        0        0        0  ...    48798    48803    48820
# 1        0        0        0        0  ...    60675    61605    62533
# 2        0        0        0        0  ...    76640    76797    76940
# 3        0        0        0        0  ...    10101    10146    10170
# 4        0        0        0        0  ...    18972    18991    19005
#
#    2/21/21  2/22/21  2/23/21  2/24/21  2/25/21  2/26/21  2/27/21
# ...

# %%
df2.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  259.000000  259.000000  259.000000  259.000000  259.000000  259.000000
# mean    19.102739   28.495821    0.115830    0.123552    0.150579    0.162162
# std     24.640880   70.936043    1.743788    1.747697    1.940118    2.005022
# min    -51.796300 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      4.715658   -8.826999    0.000000    0.000000    0.000000    0.000000
# 50%     19.856270   24.603200    0.000000    0.000000    0.000000    0.000000
# 75%     39.018950   90.394950    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000   28.000000   28.000000   31.000000   32.000000
#
#           1/26/20     1/27/20     1/28/20     1/29/20  ...       2/18/21  \
# count  259.000000  259.000000  259.000000  259.000000  ...  2.590000e+02
# mean     0.216216    0.250965    0.416988    0.490347  ...  2.398179e+05
# ...

# %% [markdown]
# ### Confirmed

# %%
df3.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 2/18/21  2/19/21  2/20/21  2/21/21  2/22/21  \
# 0  32.539527 -86.644082  ...    6071     6079     6092     6117     6121
# 1  30.727750 -87.722071  ...   19324    19361    19392    19433    19461
# 2  31.868263 -85.387129  ...    2057     2061     2067     2070     2074
# 3  32.996421 -87.125115  ...    2405     2411     2414     2416     2417
# 4  33.982109 -86.567906  ...    6008     6021     6040     6042     6043
#
#    2/23/21  2/24/21  2/25/21  2/26/21  2/27/21
# ...

# %%
df3.describe()
# Out:
#                 UID        code3          FIPS          Lat        Long_  \
# count  3.340000e+03  3340.000000   3330.000000  3340.000000  3340.000000
# mean   8.342958e+07   834.491617  33061.684685    36.707212   -88.601474
# std    4.315345e+06    36.498055  18638.940791     9.062922    21.718982
# min    1.600000e+01    16.000000     60.000000   -14.271000  -174.159600
# 25%    8.401811e+07   840.000000  19079.500000    33.895587   -97.790204
# 50%    8.402921e+07   840.000000  31014.000000    38.002344   -89.486710
# 75%    8.404612e+07   840.000000  47130.500000    41.573069   -82.311265
# max    8.410000e+07   850.000000  99999.000000    69.314792   145.673900
#
#            1/22/20      1/23/20      1/24/20      1/25/20      1/26/20  ...  \
# count  3340.000000  3340.000000  3340.000000  3340.000000  3340.000000  ...
# mean      0.000299     0.000299     0.000599     0.000599     0.001497  ...
# std       0.017303     0.017303     0.024467     0.024467     0.038668  ...
# ...

# %%
def plot_corr(df, size = 20):
    corr = df.corr()
    fig, ax = plt.subplots(figsize = (size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)
    
plot_corr(df1)
corr = df1.corr()

# %%
# fig = plt.figure(figsize = (8, 2))
# ax = fig.add_subplot(111)

# ax.table(cellText = df1.values,
#           rowLabels = df1.index,
#           colLabels = df1.columns,
#           loc = "center"
#          )
# ax.set_title("Top 10 Fields of Research by Aggregated Funding Amount")

# ax.axis("off");

# %% [markdown]
# # World data

# %% [markdown]
# ### Deaths

# %%
df4.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df4.describe()
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  236017.000000  2.360170e+05  236017.000000  2.360170e+05
# mean   118009.000000  5.715800e+04    1487.719368  3.393027e+04
# std     68132.383579  1.834751e+05    4770.414639  1.474800e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     59005.000000  7.270000e+02       9.000000  1.000000e+01
# 50%    118009.000000  6.695000e+03     127.000000  1.224000e+03
# 75%    177013.000000  3.349900e+04     880.000000  1.263900e+04
# max    236017.000000  3.664050e+06  108208.000000  6.399531e+06

# %% [markdown]
# ### Recovered

# %%
df5.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/18/21  2/19/21  2/20/21  \
# 0        0        0        0        0  ...    55557    55575    55580
# 1        0        0        0        0  ...    96838    97909    99062
# 2        0        0        0        0  ...   111418   111600   111764
# 3        0        0        0        0  ...    10610    10645    10672
# 4        0        0        0        0  ...    20452    20478    20499
#
#    2/21/21  2/22/21  2/23/21  2/24/21  2/25/21  2/26/21  2/27/21
# ...

# %%
df5.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  273.000000  273.000000  274.000000  274.000000  274.000000  274.000000
# mean    20.534804   23.028143    2.032847    2.390511    3.434307    5.229927
# std     25.194592   73.596166   26.879101   26.977077   33.585238   46.743494
# min    -51.796300 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      5.152149  -19.020800    0.000000    0.000000    0.000000    0.000000
# 50%     21.694000   20.939400    0.000000    0.000000    0.000000    0.000000
# 75%     41.112900   84.250000    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...       2/18/21  \
# count   274.000000   274.000000   274.000000   274.000000  ...  2.740000e+02
# mean      7.729927    10.682482    20.357664    22.507299  ...  4.025903e+05
# ...

# %% [markdown]
# ### Confirmed

# %%
df6.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/18/21  2/19/21  2/20/21  \
# 0        0        0        0        0  ...     2430     2430     2430
# 1        0        0        0        0  ...     1617     1636     1653
# 2        0        0        0        0  ...     2950     2954     2958
# 3        0        0        0        0  ...      107      107      107
# 4        0        0        0        0  ...      498      498      498
#
#    2/21/21  2/22/21  2/23/21  2/24/21  2/25/21  2/26/21  2/27/21
# ...

# %%
df6.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  273.000000  273.000000  274.000000  274.000000  274.000000  274.000000
# mean    20.534804   23.028143    0.062044    0.065693    0.094891    0.153285
# std     25.194592   73.596166    1.027008    1.028562    1.451957    2.417550
# min    -51.796300 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      5.152149  -19.020800    0.000000    0.000000    0.000000    0.000000
# 50%     21.694000   20.939400    0.000000    0.000000    0.000000    0.000000
# 75%     41.112900   84.250000    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000   17.000000   17.000000   24.000000   40.000000
#
#           1/26/20     1/27/20     1/28/20     1/29/20  ...        2/18/21  \
# count  274.000000  274.000000  274.000000  274.000000  ...     274.000000
# mean     0.204380    0.299270    0.478102    0.485401  ...    8911.087591
# ...

# %% [markdown]
# ### onde tem mais
# * barreira geográfica: Tentar pegar rio grande do sul (desenhar retângulo?)
# * descobrir sistema de coordenadas geográficas
# * distancia linear entre os casos, pra ver se estão relacionados
# * ferramenta de visualização do professor comba: qual dataset usado https://www.ufrgs.br/coronavis/
# * verificar: https://agencia.fapesp.br/covid-19-data-sharing-br-disponibiliza-novos-dados/35242/
